# %% [markdown]
# <a href="https://colab.research.google.com/github/chiarabaruae/TPBIGDATA/blob/main/S6_Chiara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
def scraping_ingredientes():  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.superseis.com.py/search.aspx?searchterms=cebolla')
    content = r.content
    soup = BeautifulSoup(content)

    listado = []
    for d in soup.find_all('div', attrs={'class':'item-box'}):
        nombre_producto = d.find('h2', attrs={'class':'product-title'})
        precio_producto = d.find('div', attrs={'class':'prices'})

        listado1=[]

        if nombre_producto is not None:
            listado1.append(nombre_producto.text)
        else:
            listado1.append("producto desconocido")
 
        if precio_producto is not None:
            listado1.append(precio_producto.text)
        else:
            listado1.append('0')
        listado.append(listado1)    
    return listado

# %%
resultados = []
resultados.append(scraping_ingredientes())
resultados
# Out:
# [[['\nCEBOLLA BLANCA X KG\n', '\nGs   22.850\n'],
#   ['\nMOLHO DE SABOR CEBOLLA CARAMELIZADA POLENGHI 220GR\n',
#    '\nGs   22.100\n'],
#   ['\nCEBOLLA DE 1RA X KL\n', '\nGs   6.950\n'],
#   ['\nPANCITO CON CEBOLLA S6 X KG\n', '\nGs   22.000\n'],
#   ['\nCEBOLLA DE CABEZA CON HOJA\n', '\nGs   3.900\n'],
#   ['\nPAPAS FRITAS SABOR CREMA CEBOLLA KRYZPO 37GR\n', '\nGs   5.500\n'],
#   ['\nCEBOLLA DE CABEZA 1 KG ROJA KG\n', '\nGs   14.850\n'],
#   ['\nCEBOLLA EN MALLA MLL 1 KG ARGE\n', '\nGs   7.950\n'],
#   ['\nBOLSA CONDIMENTADA CON AJO Y CEBOLLA KNORR 21GR\n', '\nGs   10.200\n'],
#   ['\nAROS DE CEBOLLA 400GR AVIKO CAJA \n', '\nGs   19.500\n'],
#   ['\nCEBOLLA 36GR EL CORTE INGLES FCO\n', '\nGs   8.200\n'],
#   ['\nAROS DE CEBOLLA DULCESAR 20 GR\n', '\nGs   2.850\n'],
#   ['\nCEBOLLA MORADA EN PAQ X KG\n', '\nGs   15.500\n'],
#   ['\nMANI CON CEBOLLA/SALSA 90 GR DORI PAQUETE\n', '\nGs   4.600\n'],
#   ['\nCEBOLLA PLUMA 150GR FRUTOS DEL MAIPO PAQ\n', '\nGs   8.100\n'],
# ...

# %%
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(resultados),columns=['Nombre','Precio'])
#df.to_csv('S6_carne.csv', index=False, encoding='utf-8')
df
# Out:
#                                                Nombre            Precio
# 0                             \nCEBOLLA BLANCA X KG\n   \nGs   22.850\n
# 1   \nMOLHO DE SABOR CEBOLLA CARAMELIZADA POLENGHI...   \nGs   22.100\n
# 2                             \nCEBOLLA DE 1RA X KL\n    \nGs   6.950\n
# 3                     \nPANCITO CON CEBOLLA S6 X KG\n   \nGs   22.000\n
# 4                      \nCEBOLLA DE CABEZA CON HOJA\n    \nGs   3.900\n
# 5    \nPAPAS FRITAS SABOR CREMA CEBOLLA KRYZPO 37GR\n    \nGs   5.500\n
# 6                  \nCEBOLLA DE CABEZA 1 KG ROJA KG\n   \nGs   14.850\n
# 7                  \nCEBOLLA EN MALLA MLL 1 KG ARGE\n    \nGs   7.950\n
# 8   \nBOLSA CONDIMENTADA CON AJO Y CEBOLLA KNORR 2...   \nGs   10.200\n
# 9               \nAROS DE CEBOLLA 400GR AVIKO CAJA \n   \nGs   19.500\n
# 10               \nCEBOLLA 36GR EL CORTE INGLES FCO\n    \nGs   8.200\n
# 11                 \nAROS DE CEBOLLA DULCESAR 20 GR\n    \nGs   2.850\n
# ...

# %%
df["Precio"] = df["Precio"].str.replace('\n', '')
df["Nombre"] = df["Nombre"].str.replace('\n', '')
df
# Out:
#                                                Nombre        Precio
# 0                                 CEBOLLA BLANCA X KG   Gs   22.850
# 1   MOLHO DE SABOR CEBOLLA CARAMELIZADA POLENGHI 2...   Gs   22.100
# 2                                 CEBOLLA DE 1RA X KL    Gs   6.950
# 3                         PANCITO CON CEBOLLA S6 X KG   Gs   22.000
# 4                          CEBOLLA DE CABEZA CON HOJA    Gs   3.900
# 5        PAPAS FRITAS SABOR CREMA CEBOLLA KRYZPO 37GR    Gs   5.500
# 6                      CEBOLLA DE CABEZA 1 KG ROJA KG   Gs   14.850
# 7                      CEBOLLA EN MALLA MLL 1 KG ARGE    Gs   7.950
# 8     BOLSA CONDIMENTADA CON AJO Y CEBOLLA KNORR 21GR   Gs   10.200
# 9                   AROS DE CEBOLLA 400GR AVIKO CAJA    Gs   19.500
# 10                   CEBOLLA 36GR EL CORTE INGLES FCO    Gs   8.200
# 11                     AROS DE CEBOLLA DULCESAR 20 GR    Gs   2.850
# 12                         CEBOLLA MORADA EN PAQ X KG   Gs   15.500
# ...

# %%
df.to_csv("archivozanahoria.csv")
